# %%
print("hello world!!")
# Out:
# hello world!!

# %% [markdown]
# ## python數學運算

# %%
print ("叫我第一名!!") #str
print ('叫我第二名!!') #str
print (50)
print (65.4)
# Out:
# 叫我第一名!!
# 叫我第二名!!
# 50
# 65.4

# %%
print ("叫我第一名", 100, "分")
print ('叫我第100.2名' , 99.8 ,'分')
print ("叫我第一名", "owen")
print ("這是布林數", True)
print ("這是布林數", False)
# Out:
# 叫我第一名 100 分
# 叫我第100.2名 99.8 分
# 叫我第一名 owen
# 這是布林數 True
# 這是布林數 False

# %%
print (7+3)
print (7-3)
print (7*3)
print (7/3)
print (7//3)
print (7%3)
print (7**3)
# Out:
# 10
# 4
# 21
# 2.3333333333333335
# 2
# 1
# 343

# %%
print (int("8") +5)
# Out:
# 13
